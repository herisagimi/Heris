# %%
import pandas as pd
import folium

# %%
import requests

request_parameters = {
    "client_id": '01UZS5EKTDCED2JXHST3IMSYSEKM1TRTOIOSHJX3K2YPCUL5',
    "client_secret": 'NEWVDP2ATMPJV3P2WKN0VXBB3GBSQLRJBUGN4Q34Q44WWYVL',
    "v": '20200418',
    "section": "coffee",
    "near": "Helsinki",
    "radius": 1000,
    "limit": 50}

data = requests.get("https://api.foursquare.com/v2/venues/explore", params=request_parameters)

# %%
data.json()
# Out:
# {'meta': {'code': 200, 'requestId': '5eb2db11be61c9001ba940c2'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'geocode': {'what': '',
#    'where': 'helsinki',
#    'center': {'lat': 60.16952, 'lng': 24.93545},
#    'displayString': 'Helsinki, Finland',
#    'cc': 'FI',
#    'geometry': {'bounds': {'ne': {'lat': 60.29788198177167,
#       'lng': 25.2415192349548},
#      'sw': {'lat': 60.12648197436881, 'lng': 24.8240229894074}}},
#    'slug': 'helsinki-finland',
#    'longId': '72057594038586161'},
#   'headerLocation': 'Helsinki',
#   'headerFullLocation': 'Helsinki',
#   'headerLocationGranularity': 'city',
#   'query': 'coffee',
#   'totalResults': 86,
#   'suggestedBounds': {'ne': {'lat': 60.178172775811575,
#     'lng': 24.952162607605953},
#    'sw': {'lat': 60.160364637231424, 'lng': 24.921636447256862}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50f688d5e4b023d2f274b506',
#        'name': 'Kaffecentralen',
#        'location': {'address': 'Fredrikinkatu 59',
#         'crossStreet': 'Kansakoulukatu',
#         'lat': 60.167580051384675,
#         'lng': 24.932525558737044,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.167580051384675,
#           'lng': 24.932525558737044}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Fredrikinkatu 59 (Kansakoulukatu)',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-50f688d5e4b023d2f274b506-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ddd2d44b0fba481fc927360',
#        'name': 'Patisserie Teemu & Markus',
#        'location': {'address': 'Yrjönkatu 25',
#         'lat': 60.16789868904846,
#         'lng': 24.938189914522386,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16789868904846,
#           'lng': 24.938189914522386}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Yrjönkatu 25', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4ddd2d44b0fba481fc927360-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aec747112f0a9002c9b92ab',
#        'name': 'La Torrefazione',
#        'location': {'address': 'Mannerheimintie 22',
#         'lat': 60.170721,
#         'lng': 24.936158,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.170721,
#           'lng': 24.936158}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Mannerheimintie 22', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5aec747112f0a9002c9b92ab-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4cb879f964a520c0bb26e3',
#        'name': 'The Ounce',
#        'location': {'address': 'Fredrikinkatu 55',
#         'lat': 60.167181864669764,
#         'lng': 24.932993265254556,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.167181864669764,
#           'lng': 24.932993265254556}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Fredrikinkatu 55', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4b4cb879f964a520c0bb26e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '556f2874498e103ac120a121',
#        'name': 'Kissakahvila Helkatti',
#        'location': {'address': 'Fredrikinkatu 55',
#         'lat': 60.167274,
#         'lng': 24.933142,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.167274,
#           'lng': 24.933142}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'neighborhood': 'Kamppi',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Fredrikinkatu 55', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '56aa371be4b08b9a8d573508',
#          'name': 'Pet Café',
#          'pluralName': 'Pet Cafés',
#          'shortName': 'Pet Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-556f2874498e103ac120a121-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af1b31ff964a52054e221e3',
#        'name': 'Gran Delicato',
#        'location': {'address': 'Kalevankatu 34',
#         'crossStreet': 'Albertinkatu',
#         'lat': 60.16530152999303,
#         'lng': 24.932182913812337,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16530152999303,
#           'lng': 24.932182913812337}],
#         'postalCode': '00180',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Kalevankatu 34 (Albertinkatu)',
#          '00180 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4af1b31ff964a52054e221e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af1c9e2f964a52031e321e3',
#        'name': 'La Torrefazione',
#        'location': {'address': 'Aleksanterinkatu 50',
#         'lat': 60.168787,
#         'lng': 24.943713,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.168787,
#           'lng': 24.943713}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Aleksanterinkatu 50',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4af1c9e2f964a52031e321e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b10f0fe7269fe002cec8df8',
#        'name': 'St. George Bakery',
#        'location': {'address': 'Yrjönkatu 13',
#         'crossStreet': 'Lönnrotinkatu',
#         'lat': 60.166676133456626,
#         'lng': 24.940574203464276,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.166676133456626,
#           'lng': 24.940574203464276}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Yrjönkatu 13 (Lönnrotinkatu)',
#          '00120 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5b10f0fe7269fe002cec8df8-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d3b40291b3a000008b4fb14',
#        'name': 'Buenos Aires',
#        'location': {'address': 'Eerikinkatu 24',
#         'lat': 60.16607,
#         'lng': 24.932268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16607,
#           'lng': 24.932268}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Eerikinkatu 24', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5d3b40291b3a000008b4fb14-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5669774f498e4a9e3fc698e0',
#        'name': 'FreshStop',
#        'location': {'address': 'Elielinaukio 5',
#         'lat': 60.17260323380078,
#         'lng': 24.94004717294192,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.17260323380078,
#           'lng': 24.94004717294192}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'neighborhood': 'Kluuvi',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Elielinaukio 5', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5669774f498e4a9e3fc698e0-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5332a200498ee3bf5e738c58',
#        'name': 'Cafferino Oba',
#        'location': {'address': 'Kalevankatu 47',
#         'crossStreet': 'Abrahaminkatu',
#         'lat': 60.16442,
#         'lng': 24.929206,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16442,
#           'lng': 24.929206}],
#         'postalCode': '00180',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Kalevankatu 47 (Abrahaminkatu)',
#          '00180 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5332a200498ee3bf5e738c58-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5606c393498e9031c272e8f2',
#        'name': 'TeeMaa',
#        'location': {'address': 'Annankatu 19',
#         'lat': 60.166425,
#         'lng': 24.937644,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.166425,
#           'lng': 24.937644}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Annankatu 19', '00120 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5606c393498e9031c272e8f2-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5715322b498e0f7c01186b17',
#        'name': 'Magnum Helsinki',
#        'location': {'address': 'Vanha ylioppilastalo',
#         'crossStreet': 'Mannerheimintie 3',
#         'lat': 60.169028,
#         'lng': 24.940343,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.169028,
#           'lng': 24.940343}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Vanha ylioppilastalo (Mannerheimintie 3)',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5715322b498e0f7c01186b17-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '535fa4ec498efdc5b1059bc7',
#        'name': 'Nespresso Boutique',
#        'location': {'address': 'Keskuskatu 3',
#         'lat': 60.16836059545529,
#         'lng': 24.943036537949705,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16836059545529,
#           'lng': 24.943036537949705}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Keskuskatu 3', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-535fa4ec498efdc5b1059bc7-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b486814f964a520de4c26e3',
#        'name': 'Kakkugalleria',
#        'location': {'address': 'Fredrikinkatu 41',
#         'lat': 60.16516242666159,
#         'lng': 24.935863877334505,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16516242666159,
#           'lng': 24.935863877334505}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Fredrikinkatu 41', '00120 Helsinki', 'Suomi']},
#        'categories': [{'id': '5744ccdfe4b0c0459246b4e2',
#          'name': 'Pastry Shop',
#          'pluralName': 'Pastry Shops',
#          'shortName': 'Pastry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4b486814f964a520de4c26e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e9ad0408231878c15989647',
#        'name': 'Fratello Torrefazione',
#        'location': {'address': 'Yliopistonkatu 6',
#         'lat': 60.169775,
#         'lng': 24.947886,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.169775,
#           'lng': 24.947886}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'country': 'Suomi',
#         'formattedAddress': ['Yliopistonkatu 6', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '47222393'}},
#       'referralId': 'e-5-4e9ad0408231878c15989647-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdb1ff964a5208b5f21e3',
#        'name': 'Konditoria Café Briossi',
#        'location': {'address': 'Kalevankatu 9',
#         'lat': 60.16732018214408,
#         'lng': 24.938286947271664,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16732018214408,
#           'lng': 24.938286947271664}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Kalevankatu 9', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4adcdb1ff964a5208b5f21e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5521378a498eb68460738818',
#        'name': 'Roasberg',
#        'location': {'address': 'Mikonkatu 13',
#         'lat': 60.17042,
#         'lng': 24.945522,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.17042,
#           'lng': 24.945522},
#          {'label': 'routing',
#           'lat': 60.170476033731894,
#           'lng': 24.94552284479141}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Mikonkatu 13', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5521378a498eb68460738818-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f2634ede4b0020c308d539d',
#        'name': 'Cafetoria',
#        'location': {'address': 'Runeberginkatu 31',
#         'crossStreet': 'Sammonkatu',
#         'lat': 60.173203,
#         'lng': 24.923024,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.173203,
#           'lng': 24.923024}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'neighborhood': 'Etu-Töölö',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Runeberginkatu 31 (Sammonkatu)',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4f2634ede4b0020c308d539d-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '561a9238498e5051abaa2da3',
#        'name': 'Café Huvila',
#        'location': {'address': 'Mannerheimintie 13 B',
#         'lat': 60.174610147161715,
#         'lng': 24.933579109423015,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.174610147161715,
#           'lng': 24.933579109423015}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Mannerheimintie 13 B',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-561a9238498e5051abaa2da3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dbbf6485da3ff58ec3e0d6a',
#        'name': 'Andante',
#        'location': {'address': 'Fredrikinkatu 20',
#         'lat': 60.1628563858034,
#         'lng': 24.939082240878598,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.1628563858034,
#           'lng': 24.939082240878598}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Fredrikinkatu 20', '00120 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4dbbf6485da3ff58ec3e0d6a-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea6a8b86c255b8d9da71d83',
#        'name': 'Chaya Teekauppa',
#        'location': {'address': 'Kauppakeskus Kluuvi',
#         'lat': 60.169897962199336,
#         'lng': 24.947813315734336,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.169897962199336,
#           'lng': 24.947813315734336}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Kauppakeskus Kluuvi',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4ea6a8b86c255b8d9da71d83-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '511b5b08e4b09ccf3d1b62c8',
#        'name': 'The Boom Room',
#        'location': {'address': 'Iso Roobertinkatu 46',
#         'lat': 60.161836571883704,
#         'lng': 24.937480265996985,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.161836571883704,
#           'lng': 24.937480265996985}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Iso Roobertinkatu 46',
#          '00120 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '81272429'}},
#       'referralId': 'e-5-511b5b08e4b09ccf3d1b62c8-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdb1ff964a5208d5f21e3',
#        'name': 'Fazer Café',
#        'location': {'address': 'Kluuvikatu 3',
#         'lat': 60.16864,
#         'lng': 24.947746,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16864,
#           'lng': 24.947746}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'neighborhood': 'Kluuvi, Helsinki',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Kluuvikatu 3', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4adcdb1ff964a5208d5f21e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee758e5d5fba3533230e98e',
#        'name': 'Konditoria pH7',
#        'location': {'address': 'Ateneuminkuja 2',
#         'lat': 60.16974931671885,
#         'lng': 24.94428078027445,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16974931671885,
#           'lng': 24.94428078027445}],
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Ateneuminkuja 2', 'Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4ee758e5d5fba3533230e98e-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b68ec96f964a5206d932be3',
#        'name': 'Kanniston Leipomo',
#        'location': {'address': 'Yliopistonkatu 7',
#         'lat': 60.169851466206936,
#         'lng': 24.946213106447356,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.169851466206936,
#           'lng': 24.946213106447356}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Yliopistonkatu 7', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4b68ec96f964a5206d932be3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdb21f964a520e55f21e3',
#        'name': 'Café Bar 9',
#        'location': {'address': 'Uudenmaankatu 9',
#         'lat': 60.16491109093367,
#         'lng': 24.941953489440227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16491109093367,
#           'lng': 24.941953489440227}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Uudenmaankatu 9', '00120 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4adcdb21f964a520e55f21e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56aa2fb3498e713c21283831',
#        'name': 'Espresso House',
#        'location': {'address': 'Kauppakeskus Forum',
#         'crossStreet': 'Mannerheimintie 14-20',
#         'lat': 60.16890100252665,
#         'lng': 24.938172694630325,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16890100252665,
#           'lng': 24.938172694630325}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Kauppakeskus Forum (Mannerheimintie 14-20)',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-56aa2fb3498e713c21283831-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '590eb5caf00a703cb85b9cdf',
#        'name': "Robert's Coffee Jugend",
#        'location': {'address': 'Pohjoisesplanadi 19',
#         'crossStreet': 'Unioninkatu',
#         'lat': 60.16793847395258,
#         'lng': 24.950775054862813,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16793847395258,
#           'lng': 24.950775054862813}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'neighborhood': 'Kluuvi',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Pohjoisesplanadi 19 (Unioninkatu)',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-590eb5caf00a703cb85b9cdf-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b0683730dd31f0024995f1b',
#        'name': 'Levain',
#        'location': {'address': 'Runeberginkatu 29',
#         'crossStreet': 'Sammonkatu',
#         'lat': 60.17309410955169,
#         'lng': 24.923055701588943,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.17309410955169,
#           'lng': 24.923055701588943}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Runeberginkatu 29 (Sammonkatu)',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5b0683730dd31f0024995f1b-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4867f4f964a520dc4c26e3',
#        'name': 'Kakkugalleria',
#        'location': {'address': 'Bulevardi 34',
#         'lat': 60.1630632219242,
#         'lng': 24.93352934449283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.1630632219242,
#           'lng': 24.93352934449283}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Bulevardi 34', '00120 Helsinki', 'Suomi']},
#        'categories': [{'id': '5744ccdfe4b0c0459246b4e2',
#          'name': 'Pastry Shop',
#          'pluralName': 'Pastry Shops',
#          'shortName': 'Pastry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4b4867f4f964a520dc4c26e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1aa6ebf964a52068ee23e3',
#        'name': 'Kaakaopuu',
#        'location': {'address': 'Kauppakeskus Kamppi, E-taso',
#         'lat': 60.16945743203522,
#         'lng': 24.934363432881938,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16945743203522,
#           'lng': 24.934363432881938}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Kauppakeskus Kamppi, E-taso',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4b1aa6ebf964a52068ee23e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eee25292c5bafa619d1fb76',
#        'name': 'Brooklyn Cafe',
#        'location': {'address': 'Fredrikinkatu 19',
#         'lat': 60.161174098075975,
#         'lng': 24.941660463809963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.161174098075975,
#           'lng': 24.941660463809963}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Fredrikinkatu 19', '00120 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d179941735',
#          'name': 'Bagel Shop',
#          'pluralName': 'Bagel Shops',
#          'shortName': 'Bagels',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4eee25292c5bafa619d1fb76-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b20b9af088158002c478124',
#        'name': 'Green Hippo Café',
#        'location': {'address': 'Punavuorenkatu 2',
#         'lat': 60.16187494612139,
#         'lng': 24.94027693057612,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16187494612139,
#           'lng': 24.94027693057612}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Punavuorenkatu 2', '00120 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5b20b9af088158002c478124-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b78ff0ef964a52071e82ee3',
#        'name': 'Kahvila Marocco',
#        'location': {'address': 'Museokatu 7',
#         'lat': 60.17486802133389,
#         'lng': 24.928057601704737,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.17486802133389,
#           'lng': 24.928057601704737}],
#         'cc': 'FI',
#         'neighborhood': 'Etu-Töölö',
#         'city': 'Helsinki',
#         'state': 'Etelä-Suomi',
#         'country': 'Suomi',
#         'formattedAddress': ['Museokatu 7', 'Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4b78ff0ef964a52071e82ee3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55fa8a92498e6e88f5a10c16',
#        'name': 'Espresso House',
#        'location': {'address': 'Kampin kauppakeskus, 1. krs.',
#         'crossStreet': 'Urho Kekkosen katu 1',
#         'lat': 60.16922511738568,
#         'lng': 24.932164573183805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16922511738568,
#           'lng': 24.932164573183805}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'neighborhood': 'Kamppi',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Kampin kauppakeskus, 1. krs. (Urho Kekkosen katu 1)',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-55fa8a92498e6e88f5a10c16-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5357ad67498eb50ed24285e0',
#        'name': 'Kahvi Charlotta',
#        'location': {'address': 'Runeberginkatu 5 B',
#         'lat': 60.169011,
#         'lng': 24.928382,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.169011,
#           'lng': 24.928382}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Kamppi',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Runeberginkatu 5 B', '00100 Kamppi', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5357ad67498eb50ed24285e0-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdb1ff964a520905f21e3',
#        'name': 'Ekberg',
#        'location': {'address': 'Bulevardi 9',
#         'lat': 60.164639543439776,
#         'lng': 24.937873596734427,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.164639543439776,
#           'lng': 24.937873596734427}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'neighborhood': 'Kamppi',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Bulevardi 9', '00120 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4adcdb1ff964a520905f21e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de8a6931f6e9b5377119100',
#        'name': 'Stockmann Terrace',
#        'location': {'address': 'Aleksanterinkatu 52',
#         'lat': 60.16815802458961,
#         'lng': 24.942856842495125,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16815802458961,
#           'lng': 24.942856842495125}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Aleksanterinkatu 52',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4de8a6931f6e9b5377119100-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdb1ff964a520a65f21e3',
#        'name': 'Café Strindberg',
#        'location': {'address': 'Pohjoisesplanadi 33',
#         'lat': 60.16769007613406,
#         'lng': 24.946242569365854,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16769007613406,
#           'lng': 24.946242569365854}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Pohjoisesplanadi 33',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4adcdb1ff964a520a65f21e3-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4b6463e4b037cdb893d675',
#        'name': 'Ihana Kahvila Baari',
#        'location': {'address': 'Aleksanterinkatu 7',
#         'lat': 60.169045420343416,
#         'lng': 24.949015080928802,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.169045420343416,
#           'lng': 24.949015080928802}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'neighborhood': 'Kluuvi',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Aleksanterinkatu 7', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4f4b6463e4b037cdb893d675-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cbbee600180721e1a0ba261',
#        'name': 'Konditoria Hopia',
#        'location': {'address': 'Pohjoinen Hesperiankatu 9',
#         'lat': 60.17736331496702,
#         'lng': 24.926620841631568,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.17736331496702,
#           'lng': 24.926620841631568}],
#         'postalCode': '00260',
#         'cc': 'FI',
#         'neighborhood': 'Etu-Töölö',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Pohjoinen Hesperiankatu 9',
#          '00260 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4cbbee600180721e1a0ba261-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56506bd1498ee6bcc6eff2f7',
#        'name': 'Espresso House',
#        'location': {'address': 'Stockmann',
#         'lat': 60.16829752614405,
#         'lng': 24.942763277007028,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16829752614405,
#           'lng': 24.942763277007028}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Stockmann', '00100 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-56506bd1498ee6bcc6eff2f7-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdb21f964a520dd5f21e3',
#        'name': 'Café Esplanad',
#        'location': {'address': 'Pohjoisesplanadi 37',
#         'lat': 60.16775002876532,
#         'lng': 24.944576538563275,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.16775002876532,
#           'lng': 24.944576538563275}],
#         'postalCode': '00130',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Pohjoisesplanadi 37',
#          '00130 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4adcdb21f964a520dd5f21e3-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee0a6110aafbb3dbad821f4',
#        'name': 'Tiedekulma / Think Corner',
#        'location': {'address': 'Yliopistonkatu 4',
#         'crossStreet': 'Fabianinkatu',
#         'lat': 60.169746,
#         'lng': 24.948465,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.169746,
#           'lng': 24.948465}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'neighborhood': 'Kluuvi',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Yliopistonkatu 4 (Fabianinkatu)',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d174941735',
#          'name': 'Coworking Space',
#          'pluralName': 'Coworking Spaces',
#          'shortName': 'Coworking Space',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-4ee0a6110aafbb3dbad821f4-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5177e328e4b077ca19f2a968',
#        'name': 'Kansallismuseon kahvila',
#        'location': {'address': 'Kansallismuseo',
#         'crossStreet': 'Mannerheimintie 34',
#         'lat': 60.17511724755837,
#         'lng': 24.931936871270747,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.17511724755837,
#           'lng': 24.931936871270747}],
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Kansallismuseo (Mannerheimintie 34)',
#          'Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5177e328e4b077ca19f2a968-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '577baa7acd1080b428cc7028',
#        'name': 'Artisan Café',
#        'location': {'address': 'Vuorikatu 8',
#         'lat': 60.17092389384024,
#         'lng': 24.947550264759514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.17092389384024,
#           'lng': 24.947550264759514}],
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Vuorikatu 8', 'Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-577baa7acd1080b428cc7028-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5238643c11d2c1029cc5e106',
#        'name': 'Starbucks',
#        'location': {'address': 'Akateeminen kirjakauppa',
#         'crossStreet': 'Pohjoisesplanadi 39',
#         'lat': 60.167736932209785,
#         'lng': 24.94336882366579,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.167736932209785,
#           'lng': 24.94336882366579}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Akateeminen kirjakauppa (Pohjoisesplanadi 39)',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5238643c11d2c1029cc5e106-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5842d187126ae87468982dd1',
#        'name': 'La Torrefazione',
#        'location': {'address': 'Kampin Kortteli',
#         'crossStreet': 'Kauppakeskus Kamppi, 5. krs',
#         'lat': 60.169576054040434,
#         'lng': 24.93334842089737,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.169576054040434,
#           'lng': 24.93334842089737}],
#         'postalCode': '00100',
#         'cc': 'FI',
#         'neighborhood': 'Kamppi',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Kampin Kortteli (Kauppakeskus Kamppi, 5. krs)',
#          '00100 Helsinki',
#          'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-5842d187126ae87468982dd1-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56b745fc498e9b6fdadfff60',
#        'name': 'Cafetino',
#        'location': {'address': 'Uudenmaankatu 19',
#         'lat': 60.163982,
#         'lng': 24.939086,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 60.163982,
#           'lng': 24.939086}],
#         'postalCode': '00120',
#         'cc': 'FI',
#         'neighborhood': 'Kamppi',
#         'city': 'Helsinki',
#         'state': 'Uusimaa',
#         'country': 'Suomi',
#         'formattedAddress': ['Uudenmaankatu 19', '00120 Helsinki', 'Suomi']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-5-56b745fc498e9b6fdadfff60-49'}]}]}}

# %%
print(len(data['meta']['response']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-db1b4a01b653> in <module>
# ----> 1 print(len(data['meta']['response']))
#
# TypeError: 'Response' object is not subscriptable

# %%
d = data.json()["response"]
d.keys()
# Out:
# dict_keys(['suggestedFilters', 'geocode', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %%
d.values()
# Out:
# dict_values([{'header': 'Tap to show:', 'filters': [{'name': 'Open now', 'key': 'openNow'}]}, {'what': '', 'where': 'helsinki', 'center': {'lat': 60.16952, 'lng': 24.93545}, 'displayString': 'Helsinki, Finland', 'cc': 'FI', 'geometry': {'bounds': {'ne': {'lat': 60.29788198177167, 'lng': 25.2415192349548}, 'sw': {'lat': 60.12648197436881, 'lng': 24.8240229894074}}}, 'slug': 'helsinki-finland', 'longId': '72057594038586161'}, 'Helsinki', 'Helsinki', 'city', 'coffee', 86, {'ne': {'lat': 60.178172775811575, 'lng': 24.952162607605953}, 'sw': {'lat': 60.160364637231424, 'lng': 24.921636447256862}}, [{'type': 'Recommended Places', 'name': 'recommended', 'items': [{'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '50f688d5e4b023d2f274b506', 'name': 'Kaffecentralen', 'location': {'address': 'Fredrikinkatu 59', 'crossStreet': 'Kansakoulukatu', 'lat': 60.167580051384675, 'lng': 24.932525558737044, 'labeledLatLngs': [{'label': 'display', 'lat': 60.167580051384675, 'lng': 24.932525558737044}], 'postalCode': '00100', 'cc': 'FI', 'city': 'Helsinki', 'state': 'Uusimaa', 'country': 'Suomi', 'formattedAddress': ['Fredrikinkatu 59 (Kansakoulukatu)', '00100 Helsinki', 'Suomi']}, 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-5-50f688d5e4b023d2f274b506-0'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4ddd2d44b0fba481fc927360', 'name': 'Patisserie Teemu & Markus', 'location': {'address': 'Yrjönkatu 25', 'lat': 60.16789868904846, 'lng': 24.938189914522386, 'labeledLatLngs': [{'label': 'display', 'lat': 60.16789868904846, 'lng': 24.938189914522386}], 'postalCode': '00100', 'cc': 'FI', 'city': 'Helsinki', 'state': 'Uusimaa', 'country': 'Suomi', 'formattedAddress': ['Yrjönkatu 25', '00100 Helsinki', 'Suomi']}, 'categories': [{'id': '4bf58dd8d48988d16a941735', 'name': 'Bakery', 'pluralName': 'Bakeries', 'shortName': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-5-4ddd2d44b0fba481fc927360-1'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '5aec747112f0a9002c9b92ab', 'name': 'La Torrefazione', 'location': {'address': 'Mannerheimintie 22', 'lat': 60.170721, 'lng': 24.936158, 'labeledLatLngs': [{'label': 'display', 'lat': 60.170721, 'lng': 24.936158}], 'postalCode': '00100', 'cc': 'FI', 'city': 'Helsinki', 'state': 'Uusimaa', 'country': 'Suomi', 'formattedAddress': ['Mannerheimintie 22', '00100 Helsinki', 'Suomi']}, 'categories': [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-5-5aec747112f0a9002c9b92ab-2'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4b4cb879f964a520c0bb26e3', 'name': 'The Ounce', 'location': {'address': 'Fredrikinkatu 55', 'lat': 60.167181864669764, 'lng': 24.932993265254556, 'labeledLatLngs': [{'label': 'display', 'lat': 60.167181864669764, 'lng': 24.932993265254556}], 'postalCode': '00100', 'cc': 'FI', 'city': 'Helsinki', 'state': 'Uusimaa', 'country': 'Suomi', 'formattedAddress': ['Fredrikinkatu 55', '00100 Helsinki', 'Suomi']}, 'categories': [{'id': '4bf58dd8d48988d1dc931735', 'name': 'Tea Room', 'pluralName': 'Tea Rooms', 'shortName' ...

# %%
d["headerLocationGranularity"], d["headerLocation"], d["headerFullLocation"]
# Out:
# ('city', 'Helsinki', 'Helsinki')

# %%
d["suggestedBounds"], d["totalResults"]
# Out:
# ({'ne': {'lat': 60.178172775811575, 'lng': 24.952162607605953},
#   'sw': {'lat': 60.160364637231424, 'lng': 24.921636447256862}},
#  86)

# %%
d["geocode"]
# Out:
# {'what': '',
#  'where': 'helsinki',
#  'center': {'lat': 60.16952, 'lng': 24.93545},
#  'displayString': 'Helsinki, Finland',
#  'cc': 'FI',
#  'geometry': {'bounds': {'ne': {'lat': 60.29788198177167,
#     'lng': 25.2415192349548},
#    'sw': {'lat': 60.12648197436881, 'lng': 24.8240229894074}}},
#  'slug': 'helsinki-finland',
#  'longId': '72057594038586161'}

# %%
d["groups"][0].keys()
# Out:
# dict_keys(['type', 'name', 'items'])

# %%
d["groups"][0]["type"], d["groups"][0]["name"]
# Out:
# ('Recommended Places', 'recommended')

# %%
items = d["groups"][0]["items"]
print("number of items: %i" % len(items))
items[2]
# Out:
# number of items: 50
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '5aec747112f0a9002c9b92ab',
#   'name': 'La Torrefazione',
#   'location': {'address': 'Mannerheimintie 22',
#    'lat': 60.170721,
#    'lng': 24.936158,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 60.170721,
#      'lng': 24.936158}],
#    'postalCode': '00100',
#    'cc': 'FI',
#    'city': 'Helsinki',
#    'state': 'Uusimaa',
#    'country': 'Suomi',
#    'formattedAddress': ['Mannerheimintie 22', '00100 Helsinki', 'Suomi']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-5-5aec747112f0a9002c9b92ab-2'}

# %%
df_raw = []
for item in items:
    venue = item["venue"]
    categories, uid, name, location = venue["categories"], venue["id"], venue["name"], venue["location"]
    assert len(categories) == 1
    shortname = categories[0]["shortName"]
    address = location["address"]
    if not "postalCode" in location:
        continue
    postalcode = location["postalCode"]
    lat = location["lat"]
    lng = location["lng"]
    datarow = (uid, name, shortname, address, postalcode, lat, lng)
    df_raw.append(datarow)
df = pd.DataFrame(df_raw, columns=["uid", "name", "shortname", "address", "postalcode", "lat", "lng"])
print("found %i cafes" % len(df))
df.head()
# Out:
# found 46 cafes
#                         uid                       name    shortname  \
# 0  50f688d5e4b023d2f274b506             Kaffecentralen  Coffee Shop
# 1  4ddd2d44b0fba481fc927360  Patisserie Teemu & Markus       Bakery
# 2  5aec747112f0a9002c9b92ab            La Torrefazione         Café
# 3  4b4cb879f964a520c0bb26e3                  The Ounce     Tea Room
# 4  556f2874498e103ac120a121      Kissakahvila Helkatti     Pet Café
#
#               address postalcode        lat        lng
# 0    Fredrikinkatu 59      00100  60.167580  24.932526
# 1        Yrjönkatu 25      00100  60.167899  24.938190
# 2  Mannerheimintie 22      00100  60.170721  24.936158
# 3    Fredrikinkatu 55      00100  60.167182  24.932993
# 4    Fredrikinkatu 55      00100  60.167274  24.933142

# %%
helsinki_center = d["geocode"]["center"]
helsinki_center
# Out:
# {'lat': 60.16952, 'lng': 24.93545}

# %%
from folium import plugins

# create map of Helsinki using latitude and longitude values
map_helsinki = folium.Map(location=[helsinki_center["lat"], helsinki_center["lng"]], zoom_start=14)

def add_markers(df):
    for (j, row) in df.iterrows():
        label = folium.Popup(row["name"], parse_html=True)
        folium.CircleMarker(
            [row["lat"], row["lng"]],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_helsinki)

add_markers(df)
hm_data = df[["lat", "lng"]].as_matrix().tolist()
map_helsinki.add_child(plugins.HeatMap(hm_data))

map_helsinki

<ipython-input-57-545d8acd851e>:20: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
  hm_data = df[["lat", "lng"]].as_matrix().tolist()
